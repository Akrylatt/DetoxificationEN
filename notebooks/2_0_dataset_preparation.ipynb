# %% [markdown]
# #2.0 Preparing the dataset for the fine-tuning and testing

# %%
# downloading the provided data
# !gdown 1wG1jLCHW763jjChf99whUip8VHEUW1-S
# !unzip /content/filtered_paranmt.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wG1jLCHW763jjChf99whUip8VHEUW1-S
# To: /content/filtered_paranmt.zip
# 100% 44.4M/44.4M [00:01<00:00, 33.1MB/s]
# Archive:  /content/filtered_paranmt.zip
#   inflating: filtered.tsv

# %%
# Doing all the necessary imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# loading the data into a pandas dataframe
df = pd.read_csv('/content/filtered.tsv', sep='\t')

# %%
# Taking correctly paraphrazed toxic texts
df_filtered = df.sort_values(by='trn_tox', ascending=True).head(100000)
df_filtered.reset_index(drop=True, inplace=True)

# %%
# Create the train and test datasets
train_test_dataset = df_filtered[['reference', 'translation']]

# Split the dataset into train and test
from sklearn.model_selection import train_test_split
train, test = train_test_split(train_test_dataset, test_size=0.2, random_state=42)

# %%
train.head()
# Out:
#                                                reference  \
# 75220  Carlos, this is a stupid fucking problem to have.
# 48955                               They're right nasty.
# 44966      There's not a damn thing you can do about it.
# 13568            But darned if she understood it anyway!
# 92727  And furthermore, interpreters go to lectures, ...
#
#                                              translation
# 75220                 Carlos, this is a serious problem.
# 48955                                this is really bad!
# 44966                    you can't do anything about it.
# 13568  but she doubted if she understood at least a t...
# 92727  and, by the way, interpreters go to class, lab...

# %%
train.to_csv('train.txt', sep = '\n', index = False)
test.to_csv('test.csv', index = False)

# %% [markdown]
# ## Lets create a dataset for fine-tuning GPT-2

# %%
train['combined'] = '<s>' + train.reference + '</s>' + '>>>>' + '<p>' + train.translation + '</p>'

# %%
train.head()
# Out:
#                                                reference  \
# 75220  Carlos, this is a stupid fucking problem to have.
# 48955                               They're right nasty.
# 44966      There's not a damn thing you can do about it.
# 13568            But darned if she understood it anyway!
# 92727  And furthermore, interpreters go to lectures, ...
#
#                                              translation  \
# 75220                 Carlos, this is a serious problem.
# 48955                                this is really bad!
# 44966                    you can't do anything about it.
# 13568  but she doubted if she understood at least a t...
# 92727  and, by the way, interpreters go to class, lab...
#
#                                                 combined
# 75220  <s>Carlos, this is a stupid fucking problem to...
# 48955  <s>They're right nasty.</s>>>>><p>this is real...
# 44966  <s>There's not a damn thing you can do about i...
# 13568  <s>But darned if she understood it anyway!</s>...
# 92727  <s>And furthermore, interpreters go to lecture...

# %%
train.shape
# Out:
# (80000, 3)

# %%
train.combined.to_csv('combined.txt', sep = '\n', index = False)
